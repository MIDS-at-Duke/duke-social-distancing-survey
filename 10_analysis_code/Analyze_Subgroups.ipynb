# %% [markdown]
# # Analysis of Week 1 - Week 2 Changes

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf 
from statsmodels.stats.weightstats import DescrStatsW

svy = pd.read_csv('../20_analysis_datasets/'
                  'merged_surveys_w_analysis_vars.csv')

# %%
svy.week.value_counts()
# Out:
# week6    2004
# week2    1910
# week3    1715
# week4    1653
# week1    1603
# Name: week, dtype: int64

# %% [markdown]
# ## Behavior by Sub-population

# %%
for population in ['C(age_ranges, Treatment("< 35"))*week6', 
                   'C(race, Treatment("White"))*week6',
                   'C(college_degree)*week6']:
    for outcome in ['ever_in_group', 'any_close_interactions', 
                    'close_interactions', 'someone_working']:
        model = smf.wls(f'{outcome} ~ {population} + live_survey', 
                        svy, weights=svy['weight']).fit()
        print(model.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          ever_in_group   R-squared:                       0.037
# Model:                            WLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     35.82
# Date:                Thu, 14 May 2020   Prob (F-statistic):           3.81e-56
# Time:                        13:41:42   Log-Likelihood:                -5564.7
# No. Observations:                7558   AIC:                         1.115e+04
# Df Residuals:                    7549   BIC:                         1.121e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# =============================================================================================================================
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                     0.3465      0.015     23.512      0.000       0.318       0.375
# C(age_ranges, Treatment("< 35"))[T.35 - 55]                  -0.0656      0.015     -4.450      0.000      -0.094      -0.037
# C(age_ranges, Treatment("< 35"))[T.55 - 65]                  -0.0487      0.018     -2.741      0.006      -0.083      -0.014
# C(age_ranges, Treatment("< 35"))[T.> 65]                     -0.0194      0.018     -1.052      0.293      -0.056       0.017
# week6[T.True]                                                -0.0516      0.021     -2.407      0.016      -0.094      -0.010
# live_survey[T.True]                                          -0.1556      0.012    -13.064      0.000      -0.179      -0.132
# C(age_ranges, Treatment("< 35"))[T.35 - 55]:week6[T.True]     0.0980      0.030      3.293      0.001       0.040       0.156
# C(age_ranges, Treatment("< 35"))[T.55 - 65]:week6[T.True]     0.1076      0.032      3.318      0.001       0.044       0.171
# C(age_ranges, Treatment("< 35"))[T.> 65]:week6[T.True]        0.0687      0.033      2.084      0.037       0.004       0.133
# ==============================================================================
# Omnibus:                     2405.726   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6676.280
# Skew:                           1.706   Prob(JB):                         0.00
# Kurtosis:                       6.091   Cond. No.                         12.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     any_close_interactions   R-squared:                       0.010
# Model:                                WLS   Adj. R-squared:                  0.009
# Method:                     Least Squares   F-statistic:                     8.834
# Date:                    Thu, 14 May 2020   Prob (F-statistic):           4.20e-12
# Time:                            13:41:42   Log-Likelihood:                -5199.7
# No. Observations:                    6948   AIC:                         1.042e+04
# Df Residuals:                        6939   BIC:                         1.048e+04
# Df Model:                               8
# Covariance Type:                nonrobust
# =============================================================================================================================
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                     0.2984      0.016     18.734      0.000       0.267       0.330
# C(age_ranges, Treatment("< 35"))[T.35 - 55]                  -0.0761      0.016     -4.771      0.000      -0.107      -0.045
# C(age_ranges, Treatment("< 35"))[T.55 - 65]                  -0.0801      0.019     -4.226      0.000      -0.117      -0.043
# C(age_ranges, Treatment("< 35"))[T.> 65]                     -0.0655      0.019     -3.380      0.001      -0.103      -0.027
# week6[T.True]                                                 0.0857      0.024      3.631      0.000       0.039       0.132
# live_survey[T.True]                                          -0.0350      0.013     -2.751      0.006      -0.060      -0.010
# C(age_ranges, Treatment("< 35"))[T.35 - 55]:week6[T.True]    -0.0123      0.033     -0.373      0.709      -0.077       0.052
# C(age_ranges, Treatment("< 35"))[T.55 - 65]:week6[T.True]    -0.0194      0.035     -0.558      0.577      -0.088       0.049
# C(age_ranges, Treatment("< 35"))[T.> 65]:week6[T.True]       -0.0714      0.035     -2.039      0.041      -0.140      -0.003
# ==============================================================================
# Omnibus:                     2098.031   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5425.382
# Skew:                           1.650   Prob(JB):                         0.00
# Kurtosis:                       5.801   Cond. No.                         13.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     close_interactions   R-squared:                       0.014
# Model:                            WLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     12.05
# Date:                Thu, 14 May 2020   Prob (F-statistic):           3.14e-17
# Time:                        13:41:42   Log-Likelihood:                -12608.
# No. Observations:                6948   AIC:                         2.523e+04
# Df Residuals:                    6939   BIC:                         2.530e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# =============================================================================================================================
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                     0.6805      0.046     14.709      0.000       0.590       0.771
# C(age_ranges, Treatment("< 35"))[T.35 - 55]                  -0.1903      0.046     -4.107      0.000      -0.281      -0.099
# C(age_ranges, Treatment("< 35"))[T.55 - 65]                  -0.2082      0.055     -3.780      0.000      -0.316      -0.100
# C(age_ranges, Treatment("< 35"))[T.> 65]                     -0.2382      0.056     -4.232      0.000      -0.349      -0.128
# week6[T.True]                                                 0.3428      0.069      4.999      0.000       0.208       0.477
# live_survey[T.True]                                          -0.0597      0.037     -1.614      0.107      -0.132       0.013
# C(age_ranges, Treatment("< 35"))[T.35 - 55]:week6[T.True]    -0.0697      0.095     -0.730      0.465      -0.257       0.117
# C(age_ranges, Treatment("< 35"))[T.55 - 65]:week6[T.True]    -0.1499      0.101     -1.481      0.139      -0.348       0.048
# C(age_ranges, Treatment("< 35"))[T.> 65]:week6[T.True]       -0.2230      0.102     -2.191      0.028      -0.422      -0.023
# ==============================================================================
# Omnibus:                     6620.636   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           374066.756
# Skew:                           4.552   Prob(JB):                         0.00
# Kurtosis:                      37.774   Cond. No.                         13.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:        someone_working   R-squared:                       0.083
# Model:                            WLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     86.10
# Date:                Thu, 14 May 2020   Prob (F-statistic):          3.63e-137
# Time:                        13:41:42   Log-Likelihood:                -6585.1
# No. Observations:                7592   AIC:                         1.319e+04
# Df Residuals:                    7583   BIC:                         1.325e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# =============================================================================================================================
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                     0.6091      0.017     35.838      0.000       0.576       0.642
# C(age_ranges, Treatment("< 35"))[T.35 - 55]                  -0.0267      0.017     -1.584      0.113      -0.060       0.006
# C(age_ranges, Treatment("< 35"))[T.55 - 65]                  -0.1383      0.020     -6.790      0.000      -0.178      -0.098
# C(age_ranges, Treatment("< 35"))[T.> 65]                     -0.3885      0.021    -18.351      0.000      -0.430      -0.347
# week6[T.True]                                                 0.0018      0.025      0.075      0.940      -0.046       0.050
# live_survey[T.True]                                          -0.0077      0.014     -0.562      0.574      -0.034       0.019
# C(age_ranges, Treatment("< 35"))[T.35 - 55]:week6[T.True]    -0.0108      0.034     -0.318      0.751      -0.077       0.056
# C(age_ranges, Treatment("< 35"))[T.55 - 65]:week6[T.True]    -0.0302      0.037     -0.813      0.416      -0.103       0.043
# C(age_ranges, Treatment("< 35"))[T.> 65]:week6[T.True]       -0.0104      0.038     -0.275      0.783      -0.084       0.064
# ==============================================================================
# Omnibus:                       60.133   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.142
# Skew:                          -0.149   Prob(JB):                     4.76e-12
# Kurtosis:                       2.723   Cond. No.                         12.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          ever_in_group   R-squared:                       0.045
# Model:                            WLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     59.47
# Date:                Thu, 14 May 2020   Prob (F-statistic):           2.90e-72
# Time:                        13:41:43   Log-Likelihood:                -5546.7
# No. Observations:                7573   AIC:                         1.111e+04
# Df Residuals:                    7566   BIC:                         1.116e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                              0.2806      0.008     34.396      0.000       0.265       0.297
# C(race, Treatment("White"))[T.Black]                   0.1148      0.014      8.019      0.000       0.087       0.143
# C(race, Treatment("White"))[T.Other]                   0.0879      0.018      4.921      0.000       0.053       0.123
# week6[T.True]                                          0.0366      0.013      2.724      0.006       0.010       0.063
# live_survey[T.True]                                   -0.1552      0.010    -16.049      0.000      -0.174      -0.136
# C(race, Treatment("White"))[T.Black]:week6[T.True]    -0.0426      0.029     -1.450      0.147      -0.100       0.015
# C(race, Treatment("White"))[T.Other]:week6[T.True]    -0.1342      0.037     -3.616      0.000      -0.207      -0.061
# ==============================================================================
# Omnibus:                     2420.034   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6915.196
# Skew:                           1.697   Prob(JB):                         0.00
# Kurtosis:                       6.225   Cond. No.                         9.82
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     any_close_interactions   R-squared:                       0.007
# Model:                                WLS   Adj. R-squared:                  0.007
# Method:                     Least Squares   F-statistic:                     8.722
# Date:                    Thu, 14 May 2020   Prob (F-statistic):           1.74e-09
# Time:                            13:41:43   Log-Likelihood:                -5235.1
# No. Observations:                    6963   AIC:                         1.048e+04
# Df Residuals:                        6956   BIC:                         1.053e+04
# Df Model:                               6
# Covariance Type:                nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                              0.2334      0.009     27.307      0.000       0.217       0.250
# C(race, Treatment("White"))[T.Black]                  -0.0316      0.015     -2.136      0.033      -0.061      -0.003
# C(race, Treatment("White"))[T.Other]                   0.0056      0.019      0.289      0.772      -0.032       0.043
# week6[T.True]                                          0.0859      0.015      5.846      0.000       0.057       0.115
# live_survey[T.True]                                   -0.0009      0.010     -0.089      0.929      -0.021       0.019
# C(race, Treatment("White"))[T.Black]:week6[T.True]    -0.0354      0.031     -1.148      0.251      -0.096       0.025
# C(race, Treatment("White"))[T.Other]:week6[T.True]    -0.1583      0.041     -3.886      0.000      -0.238      -0.078
# ==============================================================================
# Omnibus:                     2384.904   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7169.710
# Skew:                           1.803   Prob(JB):                         0.00
# Kurtosis:                       6.421   Cond. No.                         9.94
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     close_interactions   R-squared:                       0.011
# Model:                            WLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     12.88
# Date:                Thu, 14 May 2020   Prob (F-statistic):           1.60e-14
# Time:                        13:41:43   Log-Likelihood:                -12642.
# No. Observations:                6963   AIC:                         2.530e+04
# Df Residuals:                    6956   BIC:                         2.534e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                              0.4725      0.025     19.081      0.000       0.424       0.521
# C(race, Treatment("White"))[T.Black]                  -0.0750      0.043     -1.750      0.080      -0.159       0.009
# C(race, Treatment("White"))[T.Other]                   0.1337      0.056      2.405      0.016       0.025       0.243
# week6[T.True]                                          0.3250      0.043      7.636      0.000       0.242       0.408
# live_survey[T.True]                                    0.0509      0.030      1.695      0.090      -0.008       0.110
# C(race, Treatment("White"))[T.Black]:week6[T.True]    -0.1481      0.089     -1.659      0.097      -0.323       0.027
# C(race, Treatment("White"))[T.Other]:week6[T.True]    -0.4929      0.118     -4.178      0.000      -0.724      -0.262
# ==============================================================================
# Omnibus:                     6812.916   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           415753.697
# Skew:                           4.730   Prob(JB):                         0.00
# Kurtosis:                      39.654   Cond. No.                         9.94
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:        someone_working   R-squared:                       0.021
# Model:                            WLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     27.06
# Date:                Thu, 14 May 2020   Prob (F-statistic):           4.27e-32
# Time:                        13:41:43   Log-Likelihood:                -6867.8
# No. Observations:                7607   AIC:                         1.375e+04
# Df Residuals:                    7600   BIC:                         1.380e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                              0.4340      0.010     45.041      0.000       0.415       0.453
# C(race, Treatment("White"))[T.Black]                  -0.0639      0.017     -3.797      0.000      -0.097      -0.031
# C(race, Treatment("White"))[T.Other]                   0.0144      0.022      0.669      0.503      -0.028       0.057
# week6[T.True]                                         -0.0086      0.016     -0.539      0.590      -0.040       0.023
# live_survey[T.True]                                    0.1325      0.011     11.552      0.000       0.110       0.155
# C(race, Treatment("White"))[T.Black]:week6[T.True]     0.0259      0.035      0.743      0.458      -0.042       0.094
# C(race, Treatment("White"))[T.Other]:week6[T.True]    -0.0109      0.045     -0.244      0.807      -0.098       0.076
# ==============================================================================
# Omnibus:                      275.832   Durbin-Watson:                   1.927
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              228.576
# Skew:                           0.351   Prob(JB):                     2.32e-50
# Kurtosis:                       2.522   Cond. No.                         9.92
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          ever_in_group   R-squared:                       0.035
# Model:                            WLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     62.49
# Date:                Thu, 14 May 2020   Prob (F-statistic):           5.70e-52
# Time:                        13:41:43   Log-Likelihood:                -5011.4
# No. Observations:                6956   AIC:                         1.003e+04
# Df Residuals:                    6951   BIC:                         1.007e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                  0.3095      0.008     36.549      0.000       0.293       0.326
# C(college_degree)[T.1.0]                  -0.0694      0.012     -5.698      0.000      -0.093      -0.046
# week6[T.True]                              0.0302      0.014      2.141      0.032       0.003       0.058
# live_survey[T.True]                       -0.1306      0.010    -13.194      0.000      -0.150      -0.111
# C(college_degree)[T.1.0]:week6[T.True]    -0.0371      0.025     -1.493      0.135      -0.086       0.012
# ==============================================================================
# Omnibus:                     2274.316   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6568.177
# Skew:                           1.734   Prob(JB):                         0.00
# Kurtosis:                       6.262   Cond. No.                         6.80
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     any_close_interactions   R-squared:                       0.007
# Model:                                WLS   Adj. R-squared:                  0.007
# Method:                     Least Squares   F-statistic:                     11.28
# Date:                    Thu, 14 May 2020   Prob (F-statistic):           4.05e-09
# Time:                            13:41:43   Log-Likelihood:                -4667.5
# No. Observations:                    6181   AIC:                             9345.
# Df Residuals:                        6176   BIC:                             9379.
# Df Model:                               4
# Covariance Type:                nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                  0.2385      0.009     25.978      0.000       0.221       0.257
# C(college_degree)[T.1.0]                  -0.0568      0.013     -4.269      0.000      -0.083      -0.031
# week6[T.True]                              0.0448      0.016      2.852      0.004       0.014       0.076
# live_survey[T.True]                        0.0083      0.011      0.763      0.446      -0.013       0.030
# C(college_degree)[T.1.0]:week6[T.True]     0.0705      0.028      2.549      0.011       0.016       0.125
# ==============================================================================
# Omnibus:                     2103.261   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6287.721
# Skew:                           1.792   Prob(JB):                         0.00
# Kurtosis:                       6.402   Cond. No.                         6.82
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     close_interactions   R-squared:                       0.010
# Model:                            WLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     15.23
# Date:                Thu, 14 May 2020   Prob (F-statistic):           2.15e-12
# Time:                        13:41:43   Log-Likelihood:                -11268.
# No. Observations:                6181   AIC:                         2.255e+04
# Df Residuals:                    6176   BIC:                         2.258e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                  0.5025      0.027     18.810      0.000       0.450       0.555
# C(college_degree)[T.1.0]                  -0.1515      0.039     -3.910      0.000      -0.227      -0.076
# week6[T.True]                              0.1995      0.046      4.367      0.000       0.110       0.289
# live_survey[T.True]                        0.0799      0.032      2.521      0.012       0.018       0.142
# C(college_degree)[T.1.0]:week6[T.True]     0.1490      0.081      1.850      0.064      -0.009       0.307
# ==============================================================================
# Omnibus:                     6056.147   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           369033.670
# Skew:                           4.735   Prob(JB):                         0.00
# Kurtosis:                      39.650   Cond. No.                         6.82
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:        someone_working   R-squared:                       0.022
# Model:                            WLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     37.87
# Date:                Thu, 14 May 2020   Prob (F-statistic):           2.20e-31
# Time:                        13:41:43   Log-Likelihood:                -6178.8
# No. Observations:                6815   AIC:                         1.237e+04
# Df Residuals:                    6810   BIC:                         1.240e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                  0.4529      0.010     43.599      0.000       0.433       0.473
# C(college_degree)[T.1.0]                  -0.0828      0.015     -5.597      0.000      -0.112      -0.054
# week6[T.True]                             -0.0176      0.017     -1.024      0.306      -0.051       0.016
# live_survey[T.True]                        0.1337      0.012     11.092      0.000       0.110       0.157
# C(college_degree)[T.1.0]:week6[T.True]     0.0394      0.030      1.304      0.192      -0.020       0.099
# ==============================================================================
# Omnibus:                      228.261   Durbin-Watson:                   1.927
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.301
# Skew:                           0.234   Prob(JB):                     1.03e-32
# Kurtosis:                       2.452   Cond. No.                         6.82
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
