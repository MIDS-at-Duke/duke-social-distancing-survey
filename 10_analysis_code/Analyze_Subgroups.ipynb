# %% [markdown]
# # Analysis of Week 1 - Week 2 Changes

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf 
from statsmodels.stats.weightstats import DescrStatsW


svy = pd.read_csv('../20_analysis_datasets/'
                  'merged_surveys_w_analysis_vars.csv')

# %%
svy.week.value_counts()
# Out:
# week2    1910
# week3    1715
# week4    1653
# week1    1603
# Name: week, dtype: int64

# %% [markdown]
# ## Behavior by Sub-population

# %%
for population in ['C(age_ranges, Treatment("< 35"))', 
                   'C(race, Treatment("White"))',
                   'C(college_degree)']:
    for outcome in ['ever_in_group', 'any_close_interactions', 
                    'close_interactions', 'someone_working']:
        model = smf.wls(f'{outcome} ~ {population} + live_survey', 
                        svy, weights=svy['weight']).fit()
        print(model.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          ever_in_group   R-squared:                       0.032
# Model:                            WLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     48.18
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           6.51e-40
# Time:                        11:01:26   Log-Likelihood:                -4117.9
# No. Observations:                5755   AIC:                             8246.
# Df Residuals:                    5750   BIC:                             8279.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       0.3437      0.016     21.838      0.000       0.313       0.375
# C(age_ranges, Treatment("< 35"))[T.35 - 55]    -0.0646      0.015     -4.382      0.000      -0.094      -0.036
# C(age_ranges, Treatment("< 35"))[T.55 - 65]    -0.0466      0.018     -2.568      0.010      -0.082      -0.011
# C(age_ranges, Treatment("< 35"))[T.> 65]       -0.0171      0.019     -0.899      0.369      -0.054       0.020
# live_survey[T.True]                            -0.1524      0.014    -11.265      0.000      -0.179      -0.126
# ==============================================================================
# Omnibus:                     1844.158   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5008.535
# Skew:                           1.729   Prob(JB):                         0.00
# Kurtosis:                       5.987   Cond. No.                         6.74
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     any_close_interactions   R-squared:                       0.007
# Model:                                WLS   Adj. R-squared:                  0.007
# Method:                     Least Squares   F-statistic:                     9.880
# Date:                    Thu, 30 Apr 2020   Prob (F-statistic):           5.81e-08
# Time:                            11:01:26   Log-Likelihood:                -3827.1
# No. Observations:                    5350   AIC:                             7664.
# Df Residuals:                        5345   BIC:                             7697.
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       0.3217      0.017     19.242      0.000       0.289       0.355
# C(age_ranges, Treatment("< 35"))[T.35 - 55]    -0.0843      0.016     -5.341      0.000      -0.115      -0.053
# C(age_ranges, Treatment("< 35"))[T.55 - 65]    -0.0979      0.019     -5.113      0.000      -0.135      -0.060
# C(age_ranges, Treatment("< 35"))[T.> 65]       -0.0854      0.020     -4.339      0.000      -0.124      -0.047
# live_survey[T.True]                            -0.0614      0.014     -4.328      0.000      -0.089      -0.034
# ==============================================================================
# Omnibus:                     1781.474   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5022.604
# Skew:                           1.781   Prob(JB):                         0.00
# Kurtosis:                       6.137   Cond. No.                         6.83
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     close_interactions   R-squared:                       0.008
# Model:                            WLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     10.42
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           2.08e-08
# Time:                        11:01:26   Log-Likelihood:                -9347.2
# No. Observations:                5350   AIC:                         1.870e+04
# Df Residuals:                    5345   BIC:                         1.874e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       0.7750      0.047     16.519      0.000       0.683       0.867
# C(age_ranges, Treatment("< 35"))[T.35 - 55]    -0.2235      0.044     -5.047      0.000      -0.310      -0.137
# C(age_ranges, Treatment("< 35"))[T.55 - 65]    -0.2801      0.054     -5.215      0.000      -0.385      -0.175
# C(age_ranges, Treatment("< 35"))[T.> 65]       -0.3187      0.055     -5.774      0.000      -0.427      -0.211
# live_survey[T.True]                            -0.1667      0.040     -4.185      0.000      -0.245      -0.089
# ==============================================================================
# Omnibus:                     5410.647   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           389495.512
# Skew:                           4.917   Prob(JB):                         0.00
# Kurtosis:                      43.627   Cond. No.                         6.83
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:        someone_working   R-squared:                       0.082
# Model:                            WLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     129.7
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):          2.85e-106
# Time:                        11:01:27   Log-Likelihood:                -4964.5
# No. Observations:                5806   AIC:                             9939.
# Df Residuals:                    5801   BIC:                             9972.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       0.6214      0.018     33.945      0.000       0.586       0.657
# C(age_ranges, Treatment("< 35"))[T.35 - 55]    -0.0309      0.017     -1.816      0.069      -0.064       0.002
# C(age_ranges, Treatment("< 35"))[T.55 - 65]    -0.1475      0.021     -7.024      0.000      -0.189      -0.106
# C(age_ranges, Treatment("< 35"))[T.> 65]       -0.3989      0.022    -18.178      0.000      -0.442      -0.356
# live_survey[T.True]                            -0.0214      0.016     -1.372      0.170      -0.052       0.009
# ==============================================================================
# Omnibus:                       85.994   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.022
# Skew:                          -0.142   Prob(JB):                     5.61e-14
# Kurtosis:                       2.586   Cond. No.                         6.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          ever_in_group   R-squared:                       0.043
# Model:                            WLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     86.00
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           1.97e-54
# Time:                        11:01:27   Log-Likelihood:                -4102.1
# No. Observations:                5768   AIC:                             8212.
# Df Residuals:                    5764   BIC:                             8239.
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                0.2759      0.009     32.336      0.000       0.259       0.293
# C(race, Treatment("White"))[T.Black]     0.1154      0.014      8.121      0.000       0.088       0.143
# C(race, Treatment("White"))[T.Other]     0.0862      0.018      4.857      0.000       0.051       0.121
# live_survey[T.True]                     -0.1459      0.011    -13.293      0.000      -0.167      -0.124
# ==============================================================================
# Omnibus:                     1885.167   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5422.208
# Skew:                           1.733   Prob(JB):                         0.00
# Kurtosis:                       6.249   Cond. No.                         3.95
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     any_close_interactions   R-squared:                       0.002
# Model:                                WLS   Adj. R-squared:                  0.001
# Method:                     Least Squares   F-statistic:                     3.470
# Date:                    Thu, 30 Apr 2020   Prob (F-statistic):             0.0155
# Time:                            11:01:27   Log-Likelihood:                -3868.7
# No. Observations:                    5363   AIC:                             7745.
# Df Residuals:                        5359   BIC:                             7772.
# Df Model:                               3
# Covariance Type:                nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                0.2456      0.009     27.914      0.000       0.228       0.263
# C(race, Treatment("White"))[T.Black]    -0.0329      0.015     -2.264      0.024      -0.061      -0.004
# C(race, Treatment("White"))[T.Other]     0.0109      0.019      0.575      0.565      -0.026       0.048
# live_survey[T.True]                     -0.0265      0.012     -2.292      0.022      -0.049      -0.004
# ==============================================================================
# Omnibus:                     2006.907   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6648.799
# Skew:                           1.934   Prob(JB):                         0.00
# Kurtosis:                       6.847   Cond. No.                         3.95
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     close_interactions   R-squared:                       0.003
# Model:                            WLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     5.220
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):            0.00134
# Time:                        11:01:27   Log-Likelihood:                -9383.1
# No. Observations:                5363   AIC:                         1.877e+04
# Df Residuals:                    5359   BIC:                         1.880e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                0.5196      0.025     21.122      0.000       0.471       0.568
# C(race, Treatment("White"))[T.Black]    -0.0802      0.041     -1.972      0.049      -0.160      -0.000
# C(race, Treatment("White"))[T.Other]     0.1542      0.053      2.918      0.004       0.051       0.258
# live_survey[T.True]                     -0.0481      0.032     -1.489      0.137      -0.111       0.015
# ==============================================================================
# Omnibus:                     5535.094   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           422803.390
# Skew:                           5.070   Prob(JB):                         0.00
# Kurtosis:                      45.300   Cond. No.                         3.95
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:        someone_working   R-squared:                       0.019
# Model:                            WLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     36.90
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           1.30e-23
# Time:                        11:01:27   Log-Likelihood:                -5186.8
# No. Observations:                5819   AIC:                         1.038e+04
# Df Residuals:                    5815   BIC:                         1.041e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                0.4397      0.010     43.273      0.000       0.420       0.460
# C(race, Treatment("White"))[T.Black]    -0.0646      0.017     -3.833      0.000      -0.098      -0.032
# C(race, Treatment("White"))[T.Other]     0.0167      0.022      0.774      0.439      -0.026       0.059
# live_survey[T.True]                      0.1211      0.013      9.225      0.000       0.095       0.147
# ==============================================================================
# Omnibus:                      322.703   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              205.381
# Skew:                           0.335   Prob(JB):                     2.52e-45
# Kurtosis:                       2.368   Cond. No.                         4.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          ever_in_group   R-squared:                       0.030
# Model:                            WLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     80.66
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           3.12e-35
# Time:                        11:01:27   Log-Likelihood:                -3696.2
# No. Observations:                5289   AIC:                             7398.
# Df Residuals:                    5286   BIC:                             7418.
# Df Model:                           2
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.3053      0.009     34.437      0.000       0.288       0.323
# C(college_degree)[T.1.0]    -0.0700      0.012     -5.776      0.000      -0.094      -0.046
# live_survey[T.True]         -0.1225      0.011    -10.901      0.000      -0.145      -0.101
# ==============================================================================
# Omnibus:                     1814.477   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5415.962
# Skew:                           1.807   Prob(JB):                         0.00
# Kurtosis:                       6.394   Cond. No.                         2.91
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               WLS Regression Results
# ==================================================================================
# Dep. Variable:     any_close_interactions   R-squared:                       0.004
# Model:                                WLS   Adj. R-squared:                  0.004
# Method:                     Least Squares   F-statistic:                     9.712
# Date:                    Thu, 30 Apr 2020   Prob (F-statistic):           6.18e-05
# Time:                            11:01:27   Log-Likelihood:                -3418.8
# No. Observations:                    4741   AIC:                             6844.
# Df Residuals:                        4738   BIC:                             6863.
# Df Model:                               2
# Covariance Type:                nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.2483      0.009     26.245      0.000       0.230       0.267
# C(college_degree)[T.1.0]    -0.0553      0.013     -4.228      0.000      -0.081      -0.030
# live_survey[T.True]         -0.0115      0.012     -0.943      0.346      -0.035       0.012
# ==============================================================================
# Omnibus:                     1747.666   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5652.037
# Skew:                           1.911   Prob(JB):                         0.00
# Kurtosis:                       6.741   Cond. No.                         2.87
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:     close_interactions   R-squared:                       0.003
# Model:                            WLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     7.808
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           0.000412
# Time:                        11:01:27   Log-Likelihood:                -8345.8
# No. Observations:                4741   AIC:                         1.670e+04
# Df Residuals:                    4738   BIC:                         1.672e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.5477      0.027     20.473      0.000       0.495       0.600
# C(college_degree)[T.1.0]    -0.1445      0.037     -3.905      0.000      -0.217      -0.072
# live_survey[T.True]         -0.0113      0.034     -0.330      0.741      -0.079       0.056
# ==============================================================================
# Omnibus:                     4952.588   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           388126.664
# Skew:                           5.159   Prob(JB):                         0.00
# Kurtosis:                      46.108   Cond. No.                         2.87
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:        someone_working   R-squared:                       0.019
# Model:                            WLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     51.45
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           7.47e-23
# Time:                        11:01:27   Log-Likelihood:                -4647.5
# No. Observations:                5195   AIC:                             9301.
# Df Residuals:                    5192   BIC:                             9321.
# Df Model:                           2
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.4589      0.011     41.771      0.000       0.437       0.480
# C(college_degree)[T.1.0]    -0.0820      0.015     -5.526      0.000      -0.111      -0.053
# live_survey[T.True]          0.1222      0.014      8.842      0.000       0.095       0.149
# ==============================================================================
# Omnibus:                      310.717   Durbin-Watson:                   1.933
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              146.207
# Skew:                           0.216   Prob(JB):                     1.78e-32
# Kurtosis:                       2.301   Cond. No.                         2.94
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
